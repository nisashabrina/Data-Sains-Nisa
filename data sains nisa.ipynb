# %%
#Import pandas untuk input file csv
import pandas as pd

# %%
#Input data food delivery
data = pd.read_csv(r'E:/data sains/food_delivery_datasets.csv')
print(data)
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 0     FOOD-10455               0  2018-08-12T20:35:08.001006         1800
# 1     FOOD-10985               0  2018-09-23T17:44:12.243273         2173
# 2     FOOD-10911               0  2018-09-19T18:08:09.387991         1418
# 3     FOOD-10932               0  2018-09-21T01:24:35.272499         1903
# 4     FOOD-10961               0  2018-09-22T17:57:45.523161         1716
# ...          ...             ...                         ...          ...
# 1071  FOOD-10921               0  2018-09-20T15:01:52.152828          900
# 1072  FOOD-10265            5000  2018-07-26T14:43:23.655294         1579
# 1073  FOOD-10534               0  2018-08-21T20:10:59.283185         2606
# 1074  FOOD-10158               0  2018-07-16T14:42:23.214427         2428
# 1075  FOOD-10770               0  2018-09-11T14:18:19.494258         1547
#
#       food_price  cust_id  rating  delivery_fee   resto_id     status  \
# ...

# %%
# Mengambil data dengan resto dan ratingnya
data[["rating","resto_id"]]
# Out:
#       rating   resto_id
# 0        5.0  742638033
# 1        5.0  742767245
# 2        NaN  742618303
# 3        5.0  742541172
# 4        NaN  742604875
# ...      ...        ...
# 1071     5.0  742742150
# 1072     5.0  742566851
# 1073     NaN  742571888
# 1074     5.0  742725064
# 1075     5.0  742594499
#
# [1076 rows x 2 columns]

# %%
#Menentukan resto dengan rating dibawah 5
Resto_rating_dibawah_5 = data.loc[data["rating"]<5]
Resto_rating_dibawah_5
# Out:
#         order_id  voucher_amount                   date_time  eta_seconds  \
# 67    FOOD-10633               0  2018-08-31T11:47:18.090120         2474
# 102   FOOD-10757               0  2018-09-09T22:14:22.172861         2401
# 161   FOOD-10440               0  2018-08-11T22:37:21.740749         1535
# 283   FOOD-10066               0  2018-07-07T12:29:31.077240         2166
# 319   FOOD-10269               0  2018-07-26T18:47:21.673104         2277
# 330   FOOD-10005               0  2018-07-01T16:31:35.700543         1341
# 491   FOOD-11048            5000  2018-09-28T19:11:10.841285         3518
# 540   FOOD-10794               0  2018-09-13T18:58:37.400931         1875
# 545   FOOD-10024               0  2018-07-03T16:59:05.943102          772
# 599   FOOD-10301               0  2018-07-30T13:02:42.141731         1298
# 605   FOOD-10294               0  2018-07-29T12:57:05.523902         1495
# 622   FOOD-10018               0  2018-07-02T20:37:07.569905         1915
# ...

# %%
Resto_rating_dibawah_5[["rating","resto_id"]]
# Out:
#       rating   resto_id
# 67       4.0  742526724
# 102      3.0  742534610
# 161      3.0  742763083
# 283      4.0  742531591
# 319      4.0  742678768
# 330      4.0  742721012
# 491      4.0  742574142
# 540      4.0  742623858
# 545      1.0  742650217
# 599      4.0  742688374
# 605      4.0  742538222
# 622      4.0  742710752
# 701      4.0  742550052
# 719      4.0  200001973
# 729      4.0  742601338
# 827      4.0  742526724
# 887      4.0  742570428
# 900      3.0  742709959
# 913      4.0  742749609
# 930      4.0  742596789
# 938      3.0  742529904
# 971      4.0  742541893
# 1048     3.0  742587112
# 1053     4.0  742538207
